# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import math
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
df = pd.read_csv(Path('../Resources/Income_All.csv'))
df.head()
# Out:
#    id  year                     expenditures  expenditure_amount  \
# 0   1  2019           Accommodation services               24927
# 1   2  2019       Actual rentals for housing               45046
# 2   3  2019              Alcoholic beverages               20762
# 3   4  2019  Alcoholic beverages and tobacco               25032
# 4   5  2019                       All groups               21318
#
#    income_amount
# 0          24971
# 1          45048
# 2          20710
# 3          25036
# 4          21318

# %%
plt.figure(figsize=(16,8))
plt.title('Income Over Time')
plt.plot(df['income_amount'])
plt.ylabel('Income', fontsize=16)
plt.xlabel('Years',fontsize=16)
plt.show()

# %%
# Create a new DF with the income column
data = df.filter(['income_amount'])

# Convert the DF to a numpy array

dataset = data.values

# Get the number of rows to train the model on

training_data_len = math.ceil(len(dataset) * .8)

training_data_len
# Out:
# 189

# %%
# Scale the Data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.45997052],
#        [0.92238242],
#        [0.3618315 ],
#        [0.46146759],
#        [0.37583491],
#        [0.14010318],
#        [0.63653324],
#        [0.34575522],
#        [0.34844995],
#        [0.28584919],
#        [0.26452163],
#        [0.391773  ],
#        [0.3623382 ],
#        [0.38094799],
#        [0.36526325],
#        [0.35978166],
#        [0.36408863],
#        [0.36408863],
#        [0.32560228],
#        [0.34695288],
#        [0.36982358],
#        [0.42051684],
#        [0.35383942],
#        [0.3504307 ],
#        [0.38359666],
#        [0.35031554],
#        [0.41042885],
#        [0.4536828 ],
#        [0.9041872 ],
#        [0.47017366],
#        [0.37935879],
#        [0.36540145],
#        [0.34359022],
#        [0.41369939],
#        [0.44582892],
#        [0.36201575],
#        [0.41641715],
#        [0.34409692],
#        [0.40950758],
#        [0.36224607],
#        [0.38106315],
#        [0.31072366],
#        [0.34626192],
#        [0.38154682],
#        [0.34467272],
#        [0.44974435],
#        [0.42360311],
#        [0.32177899],
#        [0.41482795],
#        [0.46091483],
#        [0.3264775 ],
#        [0.3520199 ],
#        [0.36756645],
#        [0.40446359],
#        [0.05985997],
#        [0.3058409 ],
#        [0.31323414],
#        [0.33847713],
#        [0.31526095],
#        [0.49124787],
#        [0.9607536 ],
#        [0.36961629],
#        [0.49497904],
#        [0.38184624],
#        [0.11895988],
#        [0.71889539],
#        [0.3459625 ],
#        [0.34340596],
#        [0.27702796],
#        [0.25279838],
#        [0.40794141],
#        [0.36229214],
#        [0.38691326],
#        [0.38099406],
#        [0.33094569],
#        [0.39672486],
#        [0.3656548 ],
#        [0.3422083 ],
#        [0.35676448],
#        [0.37829932],
#        [0.4341978 ],
#        [0.35013128],
#        [0.35432309],
#        [0.39043715],
#        [0.36293703],
#        [0.42710397],
#        [0.47008153],
#        [0.81519186],
#        [0.49334377],
#        [0.38859459],
#        [0.38122438],
#        [0.34750564],
#        [0.42606753],
#        [0.47097978],
#        [0.36950113],
#        [0.39900502],
#        [0.35229628],
#        [0.42166843],
#        [0.36968538],
#        [0.39191119],
#        [0.32143351],
#        [0.35049979],
#        [0.3933622 ],
#        [0.30579483],
#        [0.45322217],
#        [0.39716247],
#        [0.29918467],
#        [0.43131881],
#        [0.48408494],
#        [0.32781335],
#        [0.35895251],
#        [0.37279469],
#        [0.42399466],
#        [0.06278502],
#        [0.29340366],
#        [0.31655074],
#        [0.33589755],
#        [0.3041135 ],
#        [0.54636326],
#        [1.        ],
#        [0.37776959],
#        [0.50882123],
#        [0.39741582],
#        [0.0990603 ],
#        [0.74284859],
#        [0.3547607 ],
#        [0.35450735],
#        [0.26537381],
#        [0.24554332],
#        [0.42217513],
#        [0.37459118],
#        [0.38389608],
#        [0.39280943],
#        [0.35287208],
#        [0.42374131],
#        [0.38797273],
#        [0.34292229],
#        [0.36372012],
#        [0.38907826],
#        [0.45250818],
#        [0.36641485],
#        [0.36878714],
#        [0.38820305],
#        [0.36922475],
#        [0.44389424],
#        [0.48542079],
#        [0.78211802],
#        [0.524529  ],
#        [0.41591045],
#        [0.3840573 ],
#        [0.34285319],
#        [0.44483855],
#        [0.47961675],
#        [0.36936294],
#        [0.38859459],
#        [0.36466442],
#        [0.46430052],
#        [0.40186098],
#        [0.41135013],
#        [0.39225667],
#        [0.3585149 ],
#        [0.39916624],
#        [0.37205767],
#        [0.45964807],
#        [0.4189046 ],
#        [0.34600857],
#        [0.45239302],
#        [0.51432586],
#        [0.36243033],
#        [0.37210374],
#        [0.37885209],
#        [0.44714174],
#        [0.03657469],
#        [0.28361509],
#        [0.32346032],
#        [0.34656133],
#        [0.34879543],
#        [0.41800636],
#        [0.75659865],
#        [0.26751578],
#        [0.37072182],
#        [0.29416371],
#        [0.03058639],
#        [0.55509236],
#        [0.2405454 ],
#        [0.24151274],
#        [0.17361463],
#        [0.13727026],
#        [0.29685845],
#        [0.26037588],
#        [0.26320881],
#        [0.29174536],
#        [0.24515178],
#        [0.34259984],
#        [0.28658621],
#        [0.23847252],
#        [0.26682482],
#        [0.27504722],
#        [0.33764798],
#        [0.25920125],
#        [0.26839099],
#        [0.26723939],
#        [0.25629923],
#        [0.32161776],
#        [0.34683772],
#        [0.74724769],
#        [0.39310885],
#        [0.31952186],
#        [0.28361509],
#        [0.23393523],
#        [0.32044313],
#        [0.34686075],
#        [0.2611129 ],
#        [0.26611083],
#        [0.27283615],
#        [0.34432724],
#        [0.29683541],
#        [0.29448616],
#        [0.26104381],
#        [0.26237966],
#        [0.28317748],
#        [0.33472293],
#        [0.34255378],
#        [0.29879313],
#        [0.29252844],
#        [0.33879958],
#        [0.38467917],
#        [0.25924732],
#        [0.26090562],
#        [0.25897093],
#        [0.32901101],
#        [0.        ],
#        [0.18685799],
#        [0.21836565],
#        [0.25768115],
#        [0.27714312]])

# %%
# Create the training data set
# Create the scaled training data set
train_data = scaled_data[0:training_data_len , :]
# Split the Data into x_train and y_train data set
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i <= 61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.45997052, 0.92238242, 0.3618315 , 0.46146759, 0.37583491,
#        0.14010318, 0.63653324, 0.34575522, 0.34844995, 0.28584919,
#        0.26452163, 0.391773  , 0.3623382 , 0.38094799, 0.36526325,
#        0.35978166, 0.36408863, 0.36408863, 0.32560228, 0.34695288,
#        0.36982358, 0.42051684, 0.35383942, 0.3504307 , 0.38359666,
#        0.35031554, 0.41042885, 0.4536828 , 0.9041872 , 0.47017366,
#        0.37935879, 0.36540145, 0.34359022, 0.41369939, 0.44582892,
#        0.36201575, 0.41641715, 0.34409692, 0.40950758, 0.36224607,
#        0.38106315, 0.31072366, 0.34626192, 0.38154682, 0.34467272,
#        0.44974435, 0.42360311, 0.32177899, 0.41482795, 0.46091483,
#        0.3264775 , 0.3520199 , 0.36756645, 0.40446359, 0.05985997,
#        0.3058409 , 0.31323414, 0.33847713, 0.31526095, 0.49124787])]
# [0.9607536044958312]
#
# [array([0.45997052, 0.92238242, 0.3618315 , 0.46146759, 0.37583491,
#        0.14010318, 0.63653324, 0.34575522, 0.34844995, 0.28584919,
#        0.26452163, 0.391773  , 0.3623382 , 0.38094799, 0.36526325,
#        0.35978166, 0.36408863, 0.36408863, 0.32560228, 0.34695288,
#        0.36982358, 0.42051684, 0.35383942, 0.3504307 , 0.38359666,
#        0.35031554, 0.41042885, 0.4536828 , 0.9041872 , 0.47017366,
#        0.37935879, 0.36540145, 0.34359022, 0.41369939, 0.44582892,
#        0.36201575, 0.41641715, 0.34409692, 0.40950758, 0.36224607,
#        0.38106315, 0.31072366, 0.34626192, 0.38154682, 0.34467272,
#        0.44974435, 0.42360311, 0.32177899, 0.41482795, 0.46091483,
#        0.3264775 , 0.3520199 , 0.36756645, 0.40446359, 0.05985997,
#        0.3058409 , 0.31323414, 0.33847713, 0.31526095, 0.49124787]), array([0.92238242, 0.3618315 , 0.46146759, 0.37583491, 0.14010318,
#        0.63653324, 0.34575522, 0.34844995, 0.28584919, 0.26452163,
#        0.391773  , 0.3623382 , 0.38094799, 0.36526325, 0.35978166,
#        0.36408863, 0.36408863, 0.32560228, 0.34695288, 0.36982358,
#        0.42051684, 0.35383942, 0.3504307 , 0.38359666, 0.35031554,
#        0.41042885, 0.4536828 , 0.9041872 , 0.47017366, 0.37935879,
#        0.36540145, 0.34359022, 0.41369939, 0.44582892, 0.36201575,
#        0.41641715, 0.34409692, 0.40950758, 0.36224607, 0.38106315,
#        0.31072366, 0.34626192, 0.38154682, 0.34467272, 0.44974435,
#        0.42360311, 0.32177899, 0.41482795, 0.46091483, 0.3264775 ,
#        0.3520199 , 0.36756645, 0.40446359, 0.05985997, 0.3058409 ,
#        0.31323414, 0.33847713, 0.31526095, 0.49124787, 0.9607536 ])]
# [0.9607536044958312, 0.3696162881754111]

# %%
# Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (129, 60, 1)

# %%
# Build the LSTM Model
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# Complite the model
model.compile(optimizer = 'adam', loss ='mean_squared_error')

# %%
# Train the model
model.fit(x_train, y_train, batch_size = 1, epochs = 100)
# Out:
# Epoch 1/100
# 129/129 [==============================] - 9s 22ms/step - loss: 0.0265
# Epoch 2/100
# 129/129 [==============================] - 3s 23ms/step - loss: 0.0227
# Epoch 3/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0203
# Epoch 4/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0235
# Epoch 5/100
# 129/129 [==============================] - 3s 23ms/step - loss: 0.0212
# Epoch 6/100
# 129/129 [==============================] - 3s 24ms/step - loss: 0.0201
# Epoch 7/100
# 129/129 [==============================] - 3s 19ms/step - loss: 0.0217
# Epoch 8/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0206
# Epoch 9/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0207
# Epoch 10/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0203
# Epoch 11/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0208
# Epoch 12/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0206
# Epoch 13/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0199
# Epoch 14/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0198
# Epoch 15/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0211
# Epoch 16/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 17/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0205
# Epoch 18/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0198
# Epoch 19/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0203
# Epoch 20/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 21/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0209
# Epoch 22/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0204
# Epoch 23/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0203
# Epoch 24/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0192
# Epoch 25/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0199
# Epoch 26/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0200
# Epoch 27/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0199
# Epoch 28/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0204
# Epoch 29/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0198
# Epoch 30/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 31/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0191
# Epoch 32/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0200
# Epoch 33/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0199
# Epoch 34/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0197
# Epoch 35/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0193
# Epoch 36/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0200
# Epoch 37/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0194
# Epoch 38/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0197
# Epoch 39/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0193
# Epoch 40/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0188
# Epoch 41/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0205
# Epoch 42/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0193
# Epoch 43/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0195
# Epoch 44/100
# 129/129 [==============================] - 3s 19ms/step - loss: 0.0198
# Epoch 45/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0199
# Epoch 46/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0197
# Epoch 47/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 48/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 49/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 50/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0182
# Epoch 51/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0196
# Epoch 52/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0186
# Epoch 53/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0188
# Epoch 54/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0179
# Epoch 55/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0187
# Epoch 56/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0177
# Epoch 57/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0176
# Epoch 58/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0190
# Epoch 59/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0184
# Epoch 60/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0175
# Epoch 61/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0177
# Epoch 62/100
# 129/129 [==============================] - 3s 23ms/step - loss: 0.0179
# Epoch 63/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0176
# Epoch 64/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0176
# Epoch 65/100
# 129/129 [==============================] - 3s 23ms/step - loss: 0.0183
# Epoch 66/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0175
# Epoch 67/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0165
# Epoch 68/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0171
# Epoch 69/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0169
# Epoch 70/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0198
# Epoch 71/100
# 129/129 [==============================] - 3s 23ms/step - loss: 0.0197
# Epoch 72/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0193
# Epoch 73/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0174
# Epoch 74/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0172
# Epoch 75/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0161
# Epoch 76/100
# 129/129 [==============================] - 3s 19ms/step - loss: 0.0195
# Epoch 77/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0168
# Epoch 78/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0160
# Epoch 79/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0168
# Epoch 80/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0161
# Epoch 81/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0150
# Epoch 82/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0151
# Epoch 83/100
# 129/129 [==============================] - 3s 19ms/step - loss: 0.0164
# Epoch 84/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0175
# Epoch 85/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0144
# Epoch 86/100
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0178
# Epoch 87/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0172
# Epoch 88/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0178
# Epoch 89/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0193
# Epoch 90/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0191
# Epoch 91/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0186
# Epoch 92/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0184
# Epoch 93/100
# 129/129 [==============================] - 3s 20ms/step - loss: 0.0174
# Epoch 94/100
# 129/129 [==============================] - 3s 22ms/step - loss: 0.0147
# Epoch 95/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0134
# Epoch 96/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0119
# Epoch 97/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0146
# Epoch 98/100
# 129/129 [==============================] - 2s 19ms/step - loss: 0.0136
# Epoch 99/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0111
# Epoch 100/100
# 129/129 [==============================] - 3s 21ms/step - loss: 0.0113

# %%
# Create the testing data set
# Create a new array containing scaled values
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
# Convert the data to a numpy array
x_test = np.array(x_test)

# %%
# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
# Get the models predicted income
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 2/2 [==============================] - 1s 12ms/step

# %%
# Get the root mean squared error (RMSE)
rmse = np.sqrt( np.mean( predictions - y_test )**2 )
rmse
# Out:
# 3341.824925199468

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

# Visualize the Data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.ylabel('Income', fontsize=16)
plt.xlabel('Date',fontsize=16)
plt.plot(train['income_amount'])
plt.plot(valid[['income_amount', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'])
plt.show()
# Out:
# C:\Users\Logan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Show the valid and predicted incomes
valid
# Out:
#      income_amount   Predictions
# 189          16305  23940.550781
# 190          16428  31094.111328
# 191          17667  28595.843750
# 192          15644  23163.328125
# 193          19875  22083.777344
# 194          17443  18832.306641
# 195          15354  18857.955078
# 196          16585  21516.523438
# 197          16942  20778.562500
# 198          19660  18842.205078
# 199          16254  16735.257812
# 200          16653  16793.177734
# 201          16603  21129.349609
# 202          16128  26079.472656
# 203          18964  25420.019531
# 204          20059  22538.521484
# 205          37444  22025.796875
# 206          22068  22754.228516
# 207          18873  24554.523438
# 208          17314  19785.634766
# 209          15157  18504.011719
# 210          18913  21381.054688
# 211          20060  20122.044922
# 212          16337  17994.949219
# 213          16554  16059.679688
# 214          16846  16502.351562
# 215          19950  20994.445312
# 216          17888  28046.628906
# 217          17786  28510.642578
# 218          16334  23547.400391
# 219          16392  21684.582031
# 220          17295  21472.541016
# 221          19533  20588.851562
# 222          19873  19936.501953
# 223          17973  19976.375000
# 224          17701  20660.644531
# 225          19710  21558.421875
# 226          21702  22444.974609
# 227          16256  23294.082031
# 228          16328  23375.521484
# 229          16244  22177.925781
# 230          19285  20849.166016
# 231           5000  20071.757812
# 232          13113  17770.054688
# 233          14481  14884.692383
# 234          16188  10113.507812
# 235          17033  11216.815430

# %%
import seaborn as sns
df = df.drop(columns='id')
sns.pairplot(df)

# %%
sns.pairplot(valid)

# %%
sns.distplot(df['income_amount'])
# Out:
# C:\Users\Logan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='income_amount', ylabel='Density'>

# %%
sns.distplot(valid)
# Out:
# C:\Users\Logan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\Logan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4574.362948803191
# MSE: 37532333.85350893
# RMSE: 6126.363836200795
